# %% [markdown]
# <a href="https://colab.research.google.com/github/rachelyayra/object-detectors/blob/main/Copy_of_face_detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mounting google colab on drive

# %%
#Connecting or mounting google drive on google collab to allow access to files on Google Collab
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %% [markdown]
# Packages needed

# %%
import dlib
import cmake
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %% [markdown]
# function for loading the image

# %%
def loadImage(path):

  return cv2.imread(path,cv2.IMREAD_COLOR)

# %% [markdown]
# Load the image

# %%
pic = loadImage('/content/gdrive/MyDrive/facepics/2 face kim.jpg')

# %% [markdown]
# function for converting dlib rectagles to bounding boxes

# %%
def rect_to_bb(rect):
    # take a bounding predicted by dlib and convert it
    # to the format (x, y, w, h) as we would normally do
    # with OpenCV
    xmin = rect.left()
    ymin = rect.top()
    xmax = rect.right() - xmin
    ymax = rect.bottom() - ymin

    # return a tuple of (x, y, w, h)
    return (xmin, ymin, xmax, ymax)

# %% [markdown]
# Face dectector

# %%
detector = dlib.get_frontal_face_detector() #initialise face dectector
face = detector(image) #detect face
numberOfFaces = len(face) 
listOfbb = []
for rect in face:
  listOfbb.append(rect_to_bb(rect))

color = (255, 0, 0)
dispImage = cv2_imshow(image)
for num in listOfbb:
  rect_img = cv2.rectangle(image,num,color)
print("There are "+str(numberOfFaces)+ " faces")
# Out:
# <PIL.Image.Image image mode=RGB size=226x223 at 0x7FB4EE2E2690>
# There are 2 faces

# %%
faceDetector(pic)
# Out:
# <PIL.Image.Image image mode=RGB size=226x223 at 0x7FB4EE8A1550>
# There are 2 faces
