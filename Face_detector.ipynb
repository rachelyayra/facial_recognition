# %% [markdown]
# <a href="https://colab.research.google.com/github/rachelyayra/facial_recognition/blob/main/Face_detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Mounting on Google Drive**

# %%
#Connecting or mounting google drive on google collab to allow access to files on Google Collab
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# **Importing Relevant Libraries**

# %%
import dlib
import cmake
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %% [markdown]
# **Function for loading images**

# %%
def loadImage(path):
  return cv2.imread(path,cv2.IMREAD_COLOR)

# %% [markdown]
# **Load Image**

# %%
pic = loadImage('/content/gdrive/MyDrive/facepics/2 face kim.jpg')

# %% [markdown]
# **Function for converting dlib rectagles to bounding boxes**

# %%
def rect_to_bb(rect):
    # take a bounding predicted by dlib and convert it
    # to the format (x, y, w, h) as we would normally do
    # with OpenCV
    xmin = rect.left()
    ymin = rect.top()
    xmax = rect.right() - xmin
    ymax = rect.bottom() - ymin

    # return a tuple of (x, y, w, h)
    return (xmin, ymin, xmax, ymax)

# %% [markdown]
# **Face dectector**

# %%
def faceDetector(image):
  detector = dlib.get_frontal_face_detector() #initialise face dectector
  face = detector(image) #detect face
  numberOfFaces = len(face)
  listOfbb = []
  for rect in face:
    listOfbb.append(rect_to_bb(rect))

  color = (255, 0, 0)
  for num in listOfbb:
    rect_img = cv2.rectangle(image,num,color)
  print("There are "+str(numberOfFaces)+ " faces in this picture.")
  cv2_imshow(rect_img)

# %% [markdown]
# **TEST**

# %%
faceDetector(pic)
# Out:
# [(125, 45, 72, 72), (53, 61, 72, 72)]
# There are 2 faces
# <PIL.Image.Image image mode=RGB size=226x223>
